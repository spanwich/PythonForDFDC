# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\aaqaifqrwn\\face_00001f1.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
from PIL import Image

src = np.array(Image.open('E:\\Train_dataset\\dfdc_train_part_00_faces\\aaqaifqrwn\\face_00001f1.jpg'))
mask = np.array(Image.open('C:\\Users\\xalanaseon\\Pictures\\mask.jpg').resize(src.shape[1::-1], Image.BILINEAR))
mask = mask / 255
dst = src * mask
Image.fromarray(dst.astype(np.uint8)).save('E:\\Train_dataset\\dfdc_train_part_00_faces\\aaqaifqrwn\\face_00001f1_mask.jpg')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\aaqaifqrwn\\face_00001f1_mask.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
from PIL import Image

src = np.array(Image.open('E:\\Train_dataset\\dfdc_train_part_00_faces\\uikpmbsozb\\face_00001f1.jpg'))
mask = np.array(Image.open('C:\\Users\\xalanaseon\\Pictures\\mask.jpg').resize(src.shape[1::-1], Image.BILINEAR))
mask = mask
dst = src * mask
Image.fromarray(dst.astype(np.uint8)).save('E:\\Train_dataset\\dfdc_train_part_00_faces\\uikpmbsozb\\face_00001f1_mask.jpg')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\uikpmbsozb\\face_00001f1_mask.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
from PIL import Image

src = np.array(Image.open('E:\\Train_dataset\\dfdc_train_part_00_faces\\uccwyoqmtq\\face_00001f1.jpg'))
mask = np.array(Image.open('C:\\Users\\xalanaseon\\Pictures\\mask.jpg').resize(src.shape[1::-1], Image.BILINEAR))
mask = mask
dst = src * mask
Image.fromarray(dst.astype(np.uint8)).save('E:\\Train_dataset\\dfdc_train_part_00_faces\\uccwyoqmtq\\face_00001f1_mask.jpg')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\uccwyoqmtq\\face_00001f1_mask.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
from PIL import Image

src = np.array(Image.open('E:\\Train_dataset\\dfdc_train_part_00_faces\\xugmhbetrw\\face_00001f1.jpg'))
mask = np.array(Image.open('C:\\Users\\xalanaseon\\Pictures\\mask.jpg').resize(src.shape[1::-1], Image.BILINEAR))
mask = mask
dst = src * mask
Image.fromarray(dst.astype(np.uint8)).save('E:\\Train_dataset\\dfdc_train_part_00_faces\\xugmhbetrw\\face_00001f1_mask.jpg')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\xugmhbetrw\\face_00001f1_mask.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Real Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\msoqnkucal\\face_00001f1.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
rows, cols = img.shape
crow,ccol = int(round(rows/2)) , int(round(cols/2))
crow2,ccol2 = rows - crow , cols - ccol
# create a mask first, center square is 1, remaining all zeros
mask = np.zeros((rows,cols,2),np.uint8)
mask[crow-crow2:crow+crow, ccol-ccol2:ccol+ccol] = 1
# apply mask and inverse DFT
fshift = dft_shift*mask
f_ishift = np.fft.ifftshift(fshift)
img_back = cv.idft(f_ishift)
img_back = cv.magnitude(img_back[:,:,0],img_back[:,:,1])
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_back, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread('E:\\Train_dataset\\dfdc_train_part_00_faces\\msoqnkucal\\face_00001f1.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

rows, cols = img.shape
print(rows,cols)
crow,ccol = int(round(rows//2)) , int(round(cols//2))
crow2,ccol2 = rows - crow , cols - ccol
print(crow2,ccol2)
fshift[crow-crow:crow+crow2, ccol-ccol:ccol+ccol2] = 0
f_ishift = np.fft.ifftshift(fshift)
img_back = np.fft.ifft2(f_ishift)
img_back = np.real(img_back)
plt.subplot(131),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(img_back, cmap = 'gray')
plt.title('Image after HPF'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(img_back)
plt.title('Result in JET'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 16), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('C:\\Users\\xalanaseon\\Documents\\Experiment\\Frame_00096.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 16), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('C:\\Users\\xalanaseon\\Documents\\Experiment\\Frame_00097.jpg',0)
dft = cv.dft(np.float32(img),flags = cv.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
magnitude_spectrum = 20*np.log(cv.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 16), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('C:\\Users\\xalanaseon\\Documents\\Experiment\\Frame_00096.jpg',0)
edges = cv.Canny(img,0,50)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Tampered Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 16), dpi=80, facecolor='w', edgecolor='k')

img = cv.imread('C:\\Users\\xalanaseon\\Documents\\Experiment\\Frame_00095.jpg',0)
edges = cv.Canny(img,0,50)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()
